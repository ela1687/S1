# %% [markdown]
# # **Triplets pythagoriciens**
#
# ![Triplets](http://eratosthene.com/images/pythago.png)

# %% [markdown]
# Écrire une fonction Python notée $pythago(a,b,c)$ prenant pour paramètres trois entiers naturels non nuls et qui renvoie True si le triplet $(a, b, c)$ est pythagoricien et False sinon.

# %%
# Programme

# %% [markdown]
# On se demande si il existe des triplets de nombres entiers naturels consécutifs qui soient des triplets pythagoriciens, écrire un programme appelant la fonction $pythago(a,b,c)$ pour émettre une conjecture.

# %%
# Programme
