# %% [markdown]
# ![datation1](http://eratosthene.com/images/datation2.png)

# %% [markdown]
# ## **Partie C Python**
#
# On note $A_n$ l'activité du carbone 14 par minute et par gramme $n$ siècles après la mort de l'organisme étudié.
#
# Ainsi, d'après l'introduction $A_0=13,6$ désintégrations par gramme et par minutes et $(A_n)$ décroit de $1,2 ~\%$ par siècle.
#
# On considère l'algorithme suivant:
#
# ---
#
# >>1	 $~~~~n \gets 0$
#
# >>2	 $~~~~A \gets 13,6$
#
# >>3  $~~~~mesure \gets 1,44$
#
# >>4	$~~~~$Tant que $A > mesure$
#
# >>5	$~~~~~~~~~~~n \gets n + 1$
#
# >>6	 $~~~~~~~~~~~A \gets 0,988 \times A$
#
# >>7	 $~~~~$Fin tant que
#
# >>8	$~~~~$Afficher $n$
#
# ---
#
#
# 1. À quoi correspond la valeur $n$ affichée en sortie de cet algorithme ?

# %% [markdown]
# **texte en gras** **Répondre ici: ...**

# %% [markdown]
# 2. Expliquer ci-dessous, la ligne 6 de l'algorithme:

# %% [markdown]
# **Répondre ici: ...**

# %% [markdown]
# 3. Traduire cet algorithme en un programme Python dans la cellule ci-dessous, quel résultat affiche-t-il?

# %%
# Programme

# %% [markdown]
# 4. En 1991, deux randonneurs ont découvert dans les Alpes un corps momifié dans la glace. Sur cette momie baptisée Otzi, on a mesuré une activité du carbone 14 de 7,16 désintégrations par minute et par gramme. Modifier le programme pour obtenir l'âge d'Otzi.

# %% [markdown]
# **Age d'Otzi : ...**
