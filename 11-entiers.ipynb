# %% [markdown]
# >>>>>>>># **Nombres entiers particuliers**
#
# >>![](http://eratosthene.com/images/entiers1.png)

# %% [markdown]
# # **Partie A  Quelques fonctions**
#
# 1. Écrire une fonction $diviseurs(n)$ qui renvoie la liste des diviseurs de $n$.
#
# 2. Écrire une fonction $somdiv(n)$ qui calcule la somme des diviseurs de $n$.
#
# 3. Écrire une fonction $parfait(n)$ qui renvoient True si l'entier est parfait et False sinon.
#
# 4. Écrire une fonction $abondant(n)$ qui renvoient True si l'entier est abondant et False sinon.

# %%
# Ecrire les fonctions ci-dessous

# %% [markdown]
# # **Partie B   Nombres triangulaires**
#
#
# >>![](http://eratosthene.com/images/entiers2.png)
#
# Le septième nombre triangulaire $T_7$ est $1+2+3+4+5+6+7=28$
#
#
# 1.  Quel est le premier nombre triangulaire qui admet plus de cinq diviseurs?

# %% [markdown]
# **Répondre ici:**

# %% [markdown]
# 2. A l'aide d'un programme Python, déterminer le premier nombre triangulaire qui admet plus de 500 diviseurs.
