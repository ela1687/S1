# %% [markdown]
# ## **Structure et composition de l’ADN**
#
#
#
# ---
#
#
# Une chaîne d’ADN est valide  si elle n'est pas vide et si elle est formée exclusivement d’une combinaison arbitraire de nucléotides  "a" "t" "g" ou "c".
#
# La chaine brin, ci-dessous, correspond au gène antennapedia de la drosophile:

# %%
# Programme

brin="..."

# %% [markdown]
# 1. Écrire une fonction proportion qui reçoit deux arguments, une chaîne  c  et la séquence recherchée et qui retourne la proportion de la séquence dans la chaîne.

# %%
# Programme

# %% [markdown]
# 2. Ecrire un programme en Python qui demande à l’utilisateur la séquence d’un brin d’ADN et affiche la séquence complémentaire.
#
#     Par exemple, si l’utilisateur saisit la séquence suivante :
#
#    TATCGATACAAT le programme doit afficher ATAGCTATGTTA

# %%
# Programme

# %% [markdown]
# 3. Ecrire le programme en Python qui :
#
#
# * génère une séquence aléatoire de 20 nucléotides
#
# * affiche cette séquence (horizontalement)
#
# * modifie aléatoirement un nucléotide
#
# * affiche la séquence modifiée (mutée)

# %%
# Programme:

# %% [markdown]
# Une chaîne d’ADN est valide  si elle n'est pas vide et si elle est formée exclusivement d’une combinaison arbitraire de nucléotides  "a" "t" "g" ou "c".
#
# 4. Écrire une fonction valide qui renvoie True si la chaine brin est valide, False sinon.

# %%
# Programme:
