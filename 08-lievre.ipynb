# %% [markdown]
# ![lievre1](http://eratosthene.com/images/lievre1.png)

# %%
from random import*  #Module random 

# Nombre de parties gagnées par le lièvre
compteur=0

def partie():     # la fonction renvoie True si le lièvre gagne la partie
        
    PositionTortue = 0
    PositionLievre = 0
    
    while PositionTortue != 5 and PositionLievre != 5 :
        
        d = ............    # on lance le dé
        
        if d==6:
            PositionLievre = ...
        else:
            PositionTortue = ........................
    
    if PositionLievre == 5 :
        return True
    else:
        return False

# %% [markdown]
# ![lievre2](http://eratosthene.com/images/lievre2.png)
