# %% [markdown]
# >>>>>>>># **Suite de Fibonacci**
#
# >>![Fibonacci](http://eratosthene.com/images/fibonacci.png)

# %% [markdown]
# On considère l'algorithme en langage naturel ci-dessous:
#
# ---
#
#
# Initialisation : $A=0$
#
# >>$~B=1$
#
# Traitement :  Répéter 4 fois:
#
# >>>$C \gets A$
#
# >>>$A \gets B$
#
# >>>$B \gets C+B$
#
# Sortie :  $~~~~~~~~$Afficher $B$
#
#
# ---

# %% [markdown]
# Quelle est la valeur affichée en sortie d'algorithme, à quoi correspond-elle?

# %% [markdown]
# Répondre ici:

# %% [markdown]
# Écrire, en utilisant une boucle bornée, une fonction fibonacci(k) qui calcule $f_k$, c'est-à-dire qui prend en argument un entier $k \geqslant 0$ et qui renvoie
# le terme d'indice $k$ de la suite de Fibonacci. (Tester votre programme.)

# %%
# Programme:

# %% [markdown]
# Écrire un programme qui détermine le premier nombre de Fibonacci à 4 chiffres.

# %%
# Programme:
